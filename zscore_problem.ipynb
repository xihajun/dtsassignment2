# %%
import pandas as pd
import numpy as np
from time import time

# %%
col_names = ["duration","protocol_type","service","flag","src_bytes",
    "dst_bytes","land","wrong_fragment","urgent","hot","num_failed_logins",
    "logged_in","num_compromised","root_shell","su_attempted","num_root",
    "num_file_creations","num_shells","num_access_files","num_outbound_cmds",
    "is_host_login","is_guest_login","count","srv_count","serror_rate",
    "srv_serror_rate","rerror_rate","srv_rerror_rate","same_srv_rate",
    "diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count",
    "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate",
    "dst_host_srv_diff_host_rate","dst_host_serror_rate","dst_host_srv_serror_rate",
    "dst_host_rerror_rate","dst_host_srv_rerror_rate","label"]

raw_data = pd.read_csv("./kddcup.data_10_percent_corrected", header=None, names = col_names)
#raw_data['label'] = raw_data['label'].replace(['back.', 'buffer_overflow.', 'ftp_write.', 'guess_passwd.', 'imap.', 'ipsweep.', 'land.', 'loadmodule.', 'multihop.', 'neptune.', 'nmap.', 'perl.', 'phf.', 'pod.', 'portsweep.', 'rootkit.', 'satan.', 'smurf.', 'spy.', 'teardrop.', 'warezclient.', 'warezmaster.'], 'attack')

# %%
from scipy import stats

# %%
def categorical_converter(data):
    '''manually encode the three categorical columns into ordinals'''
    cols=['protocol_type','service','flag']
    for i in cols:
        data[i] = le.fit_transform(data[i])
    data = hot.fit_transform(data.loc[:,cols])

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
le = LabelEncoder()
hot = OneHotEncoder(sparse=True, handle_unknown='ignore')
categorical_converter(raw_data)

# %%
raw_data
# Out:
#         duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0              0              1       22     9        181       5450     0
# 1              0              1       22     9        239        486     0
# 2              0              1       22     9        235       1337     0
# 3              0              1       22     9        219       1337     0
# 4              0              1       22     9        217       2032     0
# 5              0              1       22     9        217       2032     0
# 6              0              1       22     9        212       1940     0
# 7              0              1       22     9        159       4087     0
# 8              0              1       22     9        210        151     0
# 9              0              1       22     9        212        786     0
# 10             0              1       22     9        210        624     0
# ...

# %%
features= raw_data.iloc[:,:raw_data.shape[1]-1]
labels= raw_data.iloc[:,raw_data.shape[1]-1:]

# %%
labels= labels.values.ravel() # this becomes a 'horizontal' array

# %%
from sklearn.model_selection import train_test_split
df= pd.DataFrame(features)
X_train, X_test, y_train, y_test = train_test_split(df, labels, train_size=0.3, test_size=0.7)

# %%
from sklearn.preprocessing import StandardScaler
zscore = StandardScaler()
X_train.iloc[:,:raw_data.shape[1]-1]=zscore.fit_transform(X_train.iloc[:,:raw_data.shape[1]-1])
#raw_data.iloc[:,:raw_data.shape[1]-1] = zscore.fit_transform(raw_data.iloc[:,:raw_data.shape[1]-1])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-100-a3033cf56a17> in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 zscore = StandardScaler()
# ----> 3 X_train.iloc[:,:raw_data.shape[1]-1]=zscore.transform(X_train.iloc[:,:raw_data.shape[1]-1])
#       4 #raw_data.iloc[:,:raw_data.shape[1]-1] = zscore.fit_transform(raw_data.iloc[:,:raw_data.shape[1]-1])
#
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/data.py in transform(self, X, y, copy)
#     737                           DeprecationWarning)
#     738
# --> 739         check_is_fitted(self, 'scale_')
#     740
#     741         copy = copy if copy is not None else self.copy
#
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     940
# ...

# %%
scaler = StandardScaler().fit(X_train)
X_train_transformed = scaler.transform(X_train) # 对训练集进行标准化处理
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:617: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %%
X_test_transformed = scaler.transform(X_test) # 对测试集进行标准化处理
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   """Entry point for launching an IPython kernel.

# %%
a= np.array([1,2,5,6,9])
a = a.reshape(-1, 1)
scaler = StandardScaler().fit(a)
a_1 = scaler.transform(a) # 对训练集进行标准化处理
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
b_1
# Out:
# array([[-1.25411943e+00],
#        [-9.05752919e-01],
#        [ 1.39346603e-01],
#        [ 1.61969524e+03],
#        [ 1.18444612e+00],
#        [ 4.87713110e-01],
#        [ 1.53281263e+00]])

# %%
c = np.array([1,2,5,6,9,1,2,5,4654,8,6,9])
c = c.reshape(-1, 1)
c_1 = scaler.transform(c) # 对训练集进行标准化处理
c_1
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[-1.25411943e+00],
#        [-9.05752919e-01],
#        [ 1.39346603e-01],
#        [ 4.87713110e-01],
#        [ 1.53281263e+00],
#        [-1.25411943e+00],
#        [-9.05752919e-01],
#        [ 1.39346603e-01],
#        [ 1.61969524e+03],
#        [ 1.18444612e+00],
#        [ 4.87713110e-01],
#        [ 1.53281263e+00]])

# %%
b = np.array([1,2,5,4654,8,6,9])
b = b.reshape(-1, 1)
b_1 = scaler.transform(b) # 对测试集进行标准化处理
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
from sklearn.cluster import KMeans
kmeans1 = KMeans(n_clusters=10, random_state=0)
kmeans2 = KMeans(n_clusters=1, random_state=0)

# %%
clf = svm.SVC()
clf.fit(X_train_transformed, y_train)
# 测试
X_test_transformed = scaler.transform(X_test) # 对测试集进行标准化处理
y_test_pred = clf.predict(X_test_transformed)

--------------------- 
作者：绳子的博客 
来源：CSDN 
原文：https://blog.csdn.net/shengchaohua163/article/details/78784984 
版权声明：本文为博主原创文章，转载请附上博文链接！
# Out:
#            label
# 320422    smurf.
# 163084    smurf.
# 380897  neptune.
# 198791    smurf.
# 365902  neptune.
# 12681    normal.
# 94262     smurf.
# 448854    smurf.
# 487465    smurf.
# 284715    smurf.
# 17493    normal.
# 82548    normal.
# 19921    normal.
# 171485    smurf.
# 457390   normal.
# 408736    smurf.
# 198383    smurf.
# 13347    normal.
# 263883    smurf.
# 398963    smurf.
# 318602    smurf.
# 346883   normal.
# 387136  neptune.
# 300074    smurf.
# 403669    smurf.
# 6836     normal.
# 391601  neptune.
# 102144    smurf.
# 222055    smurf.
# 322866    smurf.
# ...          ...
# 161400    smurf.
# 88166    normal.
# 168467    smurf.
# 56646   neptune.
# 199467    smurf.
# 111539  neptune.
# 450549   normal.
# 128829    smurf.
# 3978     normal.
# 414030    smurf.
# 482729   normal.
# 298751    smurf.
# 260842    smurf.
# 7507     normal.
# 93323     smurf.
# 488167    smurf.
# 131912    smurf.
# 458397   normal.
# 490265    smurf.
# 395564  neptune.
# ...
